# %% [markdown]
# # Laboratory Day 8: Deep Learning Introduction (Image Classification)

# %% [markdown]
# The following tutorial on Tensorflow website presents the simplest network to classify images. In this exercise, let us modernize the network and have a close look of it.
#
# Tutorial:
# https://www.tensorflow.org/tutorials/keras/classification
#
# To make you prepared, please download the tutorial, run it by your self and learn from it.
#
# **In this exercise, you do not need to start from scratch. You can re-use the above tutorial and just adjust the code there.**
#
# **Please upload the changed versions (including results) of the tutorial.**

# %% [markdown]
# **Task 1 (10 points): Classifying fashion_mnist by VGG-16**
# https://arxiv.org/pdf/1409.1556
#
# 1. Build VGG-16 by yourself and replace the network in the tutorial by VGG-16.
#
# -- Input dimension of the network is kept as 224*224
#
# -- Adjust the output dimension of VGG-16 (#classes = 10)
#
# 2. Rescale the input images of fashion_mnist to the required input dimension of VGG-16 (224*224)
#
# -- option A: rescale images by e.g. opencv and then feed them to network
#
# -- option B: add an extra layer to VGG16: tf.keras.layers.Resizing()
#
# 3. Run the script and print out the performance ("accuracy")
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Task 2 (5 points): Prediction**
# 1. Select a test image and compute predicted possibilities.
# 2. Compute the value of the loss function for this image.
# 3. Write down in equations (in text format), how the loss function is computed.
#
# **Please submit the solutions of Task 1&2 as a separate file.**

# %% [markdown]
# **Task 3 (10 points): Batch Normalization & Resnet extension **
# 1. Add batch normalizations before each pooling layers.
# 2. Convert the network to a ResNet by adding by-passing routes.
# 3. Train the network again and output performance.

# %% [markdown]
# **Task 4 (5 points): **
# 1. Select a test image and a batch normalization layer in the network.
# 2. Print out the input and output of that BN layer.
# 3. Print out the parameters of the BN layer.
# 4. Explain how the output is computed using the input.

# %% [markdown]
# **Please submit the solutions of Task 3&4 as a separate file.**
